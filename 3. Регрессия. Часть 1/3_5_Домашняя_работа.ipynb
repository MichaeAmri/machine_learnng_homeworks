# %% [markdown]
# ### Урок 5. Домашняя работа
#
# Есть два набора точек - *x_hw* и *y_hw*. В рамках домашней работы нужно
# * визуализировать набор точек
# * найти коэффициенты регрессии $w_0, w_1$ по шагам, как в уроке
# * посчитать предсказание в виде $\hat{y} = w_0 + w_1x$ и визуализировать его вместе с точками *x_hw* и *y_hw*

# %%
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt

sns.set_style('darkgrid')
theme = sns.axes_style()
theme['figure.facecolor'] = '1E1E1E'
theme['axes.facecolor'] = '0.13'
theme['axes.labelcolor'] = '0.8'
theme['text.color'] = '0.8'
theme['xtick.color'] = '0.8'
theme['ytick.color'] = '0.8'
theme['grid.color'] = '0.3'
sns.set_style('darkgrid', rc=theme)

# %%
x_hw = [50, 60, 70, 100]
y_hw = [10, 15, 40, 45]

x_hw_array = np.array([[1 for i in x_hw], x_hw]).T
y_hw_array = np.array(y_hw).reshape(len(y_hw), 1)

weight = np.linalg.inv(
    (x_hw_array.T).dot(x_hw_array)
).dot(
    x_hw_array.T
).dot(y_hw_array)

print(weight)
sns.scatterplot(x=x_hw, y=y_hw)
# Out:
# [[-22.5       ]
#  [  0.71428571]]
# <AxesSubplot:>

# %%
reg_x = np.array([min(x_hw), max(x_hw)])
reg_y = weight[0][0] + weight[1][0] * reg_x

fig, ax = plt.subplots(figsize=(12, 6))

sns.lineplot(x=reg_x, y=reg_y, color='r', linestyle='--',
    label=f'y = x * {round(weight[1][0], 2)} + ({round(weight[0][0], 2)})')

sns.scatterplot(x=x_hw, y=y_hw)
# Out:
# <AxesSubplot:>
